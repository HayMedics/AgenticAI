# %%
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display
from pypdf import PdfReader
import gradio as gr
from pydantic import BaseModel
import os

# %%
pdfReader = PdfReader("Resources/resume.pdf")
resu_summary = ""
for page in pdfReader.pages:
    text = page.extract_text()
    if text:
        resu_summary += text + "\n"
    display(Markdown(text))
# Out:
#  RESUME OF DR. AWAL OLALEKAN ABDULRAHMAN
# Medical Doctor | Data Scientist | Medical Educator | Researcher
#
#   drherwal@gmail.com |   +234 816 547 1123 |   Ilorin, Kwara State,
# Nigeria
#   [LinkedIn](https://www.linkedin.com/in/awal-abdulrahman-a53483219) |
#   [HayMedics Academy](https://www.youtube.com/@HayMedicsAcademy)
#  PROFESSIONAL SUMMARY
#
# A Medical Doctor with 8+ years of medical training and a proven track
# record in clinical practice, medical education, and neuroscience
# research. Distinguished by multiple national quiz championships and
# published research in peer-reviewed journals. Founder of HayMedics
# Academy, successfully mentoring 80+ medical students across Nigeria.
# Combines strong clinical acumen with data analytics expertise and
# entrepreneurial leadership. Passionate about advancing healthcare
# delivery through innovative research, digital education platforms, and
# evidence-based medicine. Seeking opportunities to contribute to medical
# excellence in clinical practice, research, or academic medicine.
#
#  CORE COMPETENCIES
#
# Clinical & Medical
# - Patient Assessment & Diagnosis
# - Clinical Decision Making
# - Emergency Medicine Response
# - Patient Care Management
# - Medical History Taking
# - Prescription & Treatment Planning
# - Ward Round Leadership
# - Clinical Procedures
#
# Research & Academic
# - Medical Research Design
# - Scientific Writing & Publication
# - Data Analysis & Interpretation
# - Evidence-Based Medicine
# - Systematic Review
# - Public Health Research
# - Epidemiological Studies
#
# Technical & Digital
# - Data Science & Analytics
# - Statistical Analysis (SPSS, R)
# - Medical Database Management
# - Video Production & Editing
# - E-Learning Platform Development
# - Digital Content Creation
# - Healthcare Informatics
# Leadership & Education
# - Medical Education & Curriculum Design
# - Student Mentorship & Coaching
# - Team Leadership & Management
# - Public Speaking & Presentation
# - Community Health Advocacy
# - Strategic Planning
# - Project Management
#
#  PROFESSIONAL EXPERIENCE
#
#   Medical Intern (House Officer)
# Kwara State University Teaching Hospital (KWASUTH) | November 2023 –
# November 2024
# - Completed comprehensive 12-month rotations across all major clinical
# departments
# - Managed 30+ inpatients daily under consultant supervision
# - Performed clinical procedures including venipuncture, catheterization,
# and wound care
# - Presented cases during grand rounds and departmental meetings
# - Assisted in 200+ surgical cases across various specialties
# - Conducted patient education sessions on disease prevention and health
# promotion
# - Participated in emergency response teams and critical care management
#
#  Founder & Lead Medical Educator
# HayMedics Academy | Ilorin, Nigeria | June 2022 – Present
# - Founded and scaled educational platform serving 80+ medical students
# nationwide
# - Developed comprehensive "HayMedics Neuro Course" with 30+ hours of
# content
# - Created multimedia learning resources including video tutorials,
# slides, and practice questions
# - Achieved 95% student satisfaction rate and 85% improvement in exam
# scores
# - Generated sustainable revenue stream through course subscriptions -
# Built online community of 500+ medical students for peer learning
#
#  Data Scientist
# HayMedics | February 2024 – Present
# - Analyze healthcare data to identify trends and patterns for improved
# patient care
# - Develop predictive models for disease outcomes and treatment
# effectiveness
# - Create data visualization dashboards for medical research presentations
# - Implement data-driven solutions to optimize clinical workflows -
# Collaborate with research teams on statistical analysis for
# publications
#
#  Freelance Video Editor & Content Creator
# HayMedia | April 2022 – Present
# - Created promotional materials for healthcare organizations
# - Managed content strategy for medical education platforms
#
#  EDUCATION
#
#  Bachelor of Medicine, Bachelor of Surgery (MBBS)
# University of Ilorin College of Health Sciences | October 2016 – October
# 2024
# - Completed 8-year intensive medical program with clinical rotations
# - Special focus on Neuroscience and Public health
# - Member of Research and Journal Club
#
#  West African Senior School Certificate Examination (WASSCE)
# Future Leaders Model College | 2009 – 2015
#
#  PROFESSIONAL CERTIFICATIONS
#
# Medical Neuroscience | Duke University via Coursera | 2022 -
# Advanced understanding of neurobiological basis of behavior and
# cognition
# - Clinical applications of neuroscience in medical practice Link:
# https://www.coursera.org/account/accomplishments/verify/HSKB8LVLNMJA?utm_
# source%3Dandroid%26utm_medium%3Dcertificate%26utm_content%3Dcert_image%26
# utm_campaign%3Dsharing_cta%26utm_product%3Dcourse
#
# Writing in the Sciences | Stanford University via Coursera | 2022
# - Scientific writing for peer-reviewed publications - Grant writing and
# research communication Link:
# https://www.coursera.org/account/accomplishments/verify/PCK7LL2TFLTE?utm_
# source%3Dandroid%26utm_medium%3Dcertificate%26utm_content%3Dcert_image%26
# utm_campaign%3Dsharing_cta%26utm_product%3Dcourse
#
# Statistics and Data Analysis in SPSS | Aqskill.org | 2025
# Completed a comprehensive course in Statistics & Data Analysis using
# SPSS, mastering:
# - Data analysis fundamentals: qualitative vs quantitative data,
# descriptive, inferential, predictive, and prescriptive analysis     -
# SPSS interface navigation: Data View, Variable View, Output View, and
# Syntax Editor
# - Data entry, import, cleaning, and validation from various sources
# (Excel, etc.)
# - Applied statistical techniques:
# - Descriptive statistics: mean, median, mode, standard deviation     -
# Inferential tests: correlation, simple and multiple regression, ttests,
# ANOVA/MANOVA
# - Parametric and non-parametric testing
# - Developed data visualization skills:
# - Created charts and graphs: bar charts, histograms, boxplots, pie charts
# - Customized and exported visuals for reports and presentations
# - Analyzed real-world case studies and projects:
# - Survey data, research projects, and business datasets
# - Applied SPSS techniques to drive insights and recommendations
# - Produced a professional data analysis report:
# - Applied APA formatting and statistical interpretation
# - Demonstrated ability to communicate complex findings effectively
# Mastering Microsoft PowerPoint: From Beginner to Expert | Aqskill.org |
# 2025
#
# Completed 'Mastering Microsoft PowerPoint: From Beginner to Expert' and
# I'm excited to share my new skills! This comprehensive course took me
# from the basics to advanced techniques, covering design, multimedia
# integration, animations, and effective communication strategies. I'm now
# equipped to create visually stunning, engaging presentations that drive
# results. Whether it's pitching ideas, reporting progress, or teaching
# concepts, I'm ready to elevate my professional communication. Grateful
# for the learning journey
#
# Data Analytics at Datasphere Academy
#
# Completed an intensive course covering key data analytics tools and
# techniques, including:
# - Python for data analysis and visualization
# - Power BI for business intelligence and reporting
# - SQL for database management and querying
# - Microsoft Excel for data analysis and visualization
# - Gained hands-on experience with:
# - Data cleaning and preprocessing using Pandas and NumPy
# - Data visualization using Matplotlib, Plotly, and Power BI
# - Data modeling and dashboard creation     - SQL querying and data
# aggregation
# - Developed skills in:
# - Data analysis and interpretation
# - Business intelligence and decision-making
# - Data-driven storytelling
# - Problem-solving and critical thinking
#
#
#  RESEARCH & PUBLICATIONS
#
#  Published Research
#
# 1. "Advancing Brain Health: Harnessing the Centilebrain Model for
# Enhanced Diagnosis of Mental Health Disorders"
# - Published in Annals of Medicine and Surgery (2024)
# - Co-author exploring innovative diagnostic approaches in
# psychiatry
# - [DOI Link](https://journals.lww.com/annals-of-medicine-and-
# surgery)
#
# 2. "Endovascular Techniques in the Management of Moyamoya Disease: A
# Comprehensive Review of Current Therapeutic Options"
# - Systematic review of treatment modalities
# - Contributing author
#
#  Research Projects
#
# "Knowledge, Attitude, and Practice of Seasonal Malarial Chemo-prevention
# (SMC) among Women of Child-bearing Age"
# - Principal Investigator | 2024
# - Community-based cross-sectional study in Ilorin South LGA
# - Sample size: 197 participants
# - Findings presented at departmental symposium
#
#  HONORS & ACHIEVEMENTS
#
# - National Phase Qualifier - Nigerian Academy of Neurological
# Surgeons
# Quiz (2023)
# - Ranked Top 6 nationally among 500+ participants
# - Scholarship Recipient - Academic Excellence Grant (2023/2024)
#
#  Quiz Competition Championships
# - 1st Position – Co-Participant, Inter-collegiate Quiz, LAUTECH
# (2024)
# - 1st Position - Co-Participant, Late Emeritus Professor Araoye
# Inter-collegiate Quiz,
# Ekiti (2023)
# - 2nd Runner-up - NIMSA Southwest Quizlet Competition (2022)
# - 2nd Runner-up - Co-Participant, Inter-collegiate Quiz, Lagos
# State University (2023)
# - 2nd Runner-up - Co-Participant, 11th Annual Prof. Ojuawo Ayodele
# Quiz Competition
# - 2nd Runner-up - Co-Participant, 3rd Biennial Medicus Competition,
# OAU (2024)
# - Participant - FAMSA Africa Inter-MSA Quiz (2024)
#
#
#  LEADERSHIP POSITIONS
#
# Project Manager, Al-Mustapha Medical Outreach held on December, 2025
#
# Campus Coordinator | Al-Ansor Trust Fund, COHS | 2021 – 2023
# - Managed scholarship distribution and student support services
#
# Assistant General Secretary | Muslim Student Society of Nigeria (MSSN) |
# 2022 – 2023
# - Led organizational strategy and program implementation
#
# Student Advisor | University of Ilorin Cardiothoracic Surgery Interest
# Group
# - Mentored junior students interested in surgical specialties
# Student Advisor | Mission: Brain, University of Ilorin Chapter
# - Promoted neuroscience education and brain health awareness
#
#  VOLUNTEER & COMMUNITY SERVICE
#
# - MSSN Student Doctor on Call - COHS Hostel (2018-2019)
# - Provided 24/7 medical support to 500+ hostel residents
# - Ilorin Emirate Doctors' Group Outreach - Gambari Community (2022)
# - Delivered free medical services to 300+ underserved patients
# - Power Oil Medical Outreach Program (2022)
# - Conducted health screenings and education sessions
# - Ramadan Special Program Committee Member (2023)
#
#
#  TEACHING EXPERIENCE
# Lead Medical Educator | HayMedics Academy | 2022 till present
#
# Biology Tutor | A+ Educational Consultancy | March 2022 – February 2023
# - Prepared 50+ students for WAEC and JAMB examinations
# - Developed innovative teaching methods for complex biological concepts
#
# Tutor, MSSN COHS Academic Office
# 2018 - 2021
#
#
#  PROFESSIONAL SKILLS
#
# Clinical Skills
# - Physical Examination | Clinical Diagnosis | Emergency Medicine |
# Patient Management
# - Medical Documentation | Prescription Writing | Procedure Assistance
#
# Technical Skills
# - Data Analysis: SPSS, R, Python basics | Microsoft Office Suite
# - Video Editing: Adobe Premiere Pro, DaVinci Resolve
# - E-Learning Platforms: Moodle, Google Classroom
# - Medical Databases: PubMed, Cochrane, UpToDate
#
# Languages
# - English  | Yoruba (Native) | Arabic (Basic)
#
#  PROFESSIONAL AFFILIATIONS
#
# - Nigerian Medical Association (NMA) - Member
# - Medical and Dental Council of Nigeria (MDCN) - Registered
# - Ilorin University Medical Student Association (ILUMSA)
# - Research and Journal Club Member (2023)
#
#
#  DIGITAL PRESENCE & PLATFORMS
#   YouTube: [HayMedics
# Academy](https://www.youtube.com/@HayMedicsAcademy) - 120+ subscribers
#   X (Twitter): [@HayMedics](https://x.com/HayMedics)
#   Telegram: [HayMedics Neuro Course](https://t.me/+2G9OfHAHy3M4NmRk)
#   Daily Medical Insights:
# [bit.ly/DailyHayMedicsInsights](https://bit.ly/DailyHayMedicsInsights)
#
# 🧑‍💻 My Personal Profile — Knowledge File for My AI Assistant
#
# Last updated: Thursday, 25/6/2026 at 8:00pm
#
#  1. Who I Am (Basic Identity)
#
# - Full name: Dr. Awal Olalekan Abdulrahman
# - Preferred name (what should the AI call you?): Dr. Awal
# - Title / honorifics: Dr. (Medical Doctor)
# - Pronouns (he / she / they): he
# - Date of birth: 17/11/1999
# - Age: 26 year old
# - Nationality: Nigerian
# - Home town / state of origin: Alapa/ Kwara State
# - Current city & country: Ilorin, Kwara State, Nigeria
# - Time zone: West Africa Time (WAT, UTC+1)
# - Languages I speak: English, Yoruba (Native), Arabic (Basic)
# - Religion (optional): Islam. A Salafi Muslim. Staunch student of
# knowledge
# - Marital status (optional): Married with a kid, Khadeejah.
# - Favourite Food: Combo of Rice, fish stew, beans, Chicken and chilled
# water
#
#  2. How to Reach Me (Contact & Online Presence)
#
# - Email: drherwal@gmail.com
# - Phone: +234 816 547 1123
# - LinkedIn: https://www.linkedin.com/in/awal-abdulrahman-a53483219
# - GitHub: https://github.com/HayMedics
# - Portfolio / personal website: https://haymedics.github.io
# - YouTube: HayMedics Academy — https://www.youtube.com/@HayMedicsAcademy
# - X (Twitter): @HayMedics — https://x.com/HayMedics
# - Telegram: https://t.me/+2G9OfHAHy3M4NmRk
# - WhatsApp / other: 08165471123, 08107820971
# - Email: haymedicsacademy@gmail.com, drherwal@gmail.com
#
#  3. My Professional Background
#
# - Current main role(s): Medical Doctor, Data Scientist, Medical Educator,
# AI Engineer Researcher, Founder of HayMedics Academy
# - One-line description of me: Medical doctor and founder of HayMedics
# Academy, blending clinical practice, medical education, and data science.
# - Years of experience: 8+ years of medical training. Almost 2 years of
# Practice
# - Professional summary: A Medical Doctor with 8+ years of medical
# training and a track record in clinical practice, medical education, and
# neuroscience research. Founder of HayMedics Academy, mentoring 80+
# medical students across Nigeria. Combines clinical skill with data
# analytics and entrepreneurial leadership. Strong passion for AI Engineer
# building products that solves health problem, products and solutions that
# saves time, money and lives.
#
# Work history:
# - House Officer (Medical Intern) — Kwara State University Teaching
# Hospital (KWASUTH) — Nov 2023 to Nov 2024
# - Founder & Lead Medical Educator — HayMedics Academy — June 2022 to
# Present
# - Data Scientist — HayMedics — Feb 2024 to Present
# - Freelance Video Editor & Content Creator — HayMedia — April 2022 to
# Present
# - Biology Tutor — A+ Educational Consultancy — March 2022 to Feb 2023
# - Tutor — MSSN COHS Academic Office — 2018 to 2021
#
#  4. My Education
#
# - MBBS (Bachelor of Medicine, Bachelor of Surgery) — University of
# Ilorin, College of Health Sciences (Oct 2016 – Oct 2024). Special focus
# on Neuroscience and Public Health.
# - WASSCE — Future Leaders Model College (2009 – 2015)
#
#  5. My Certifications & Courses
#
# - Medical Neuroscience — Duke University (via Coursera), 2022
# - Writing in the Sciences — Stanford University (via Coursera), 2022
# - Statistics and Data Analysis in SPSS — Aqskill.org, 2025
# - Mastering Microsoft PowerPoint — Aqskill.org, 2025
# - Data Analytics (Python, Power BI, SQL, Excel) — Datasphere Academy,
# 2025
# -  AI/Machine learning Bootcamp - Techcrush, 2026
# -  AI Bootcamp and Mentorship- MedNexAI Academy, Ongoing
# -  Agentic AI Bootcamp by Miracle, Ongoing
# -  Cloud Computing - Techcrush, Ongoing
# - Learn SPSS from scratch to advanced  in Udemy, Ongoing
# - Data 365 Bootcamp on Udemy, Ongoing
# - Python for Data Science and Machine Learning Masterclass by Jose
# Portilla on Udemy, Ongoing
#
#  6. My Skills
#
# Medical / Clinical: Patient assessment & diagnosis, clinical decision
# making, emergency medicine, patient care, medical history taking,
# prescription & treatment planning, ward round leadership, clinical
# procedures
# Research: Medical research design, scientific writing & publication, data
# analysis & interpretation, evidence-based medicine, systematic review,
# public health research, epidemiology
#
# Data & Technical: Data analysis (SPSS, R, Python basics), SQL, Power BI,
# Microsoft Excel, Pandas, NumPy, Matplotlib, Plotly, data cleaning,
# dashboards, healthcare informatics
#
# Tools & Software: Microsoft Office, Capcut, Zoom, Google meet, Jitsi
# meet, Google Classroom; medical databases (PubMed, Cochrane, UpToDate)
#
# Soft skills: Mentorship, public speaking, team leadership, project
# management, strategic planning, teaching
#
# Languages (human): English, Yoruba (Native), Arabic (Basic)
#
#  7. My Research & Publications
#
# - "Advancing Brain Health: Harnessing the Centilebrain Model for Enhanced
# Diagnosis of Mental Health Disorders" — Annals of Medicine and Surgery
# (2024), co-author
# - "Endovascular Techniques in the Management of Moyamoya Disease: A
# Comprehensive Review of Current Therapeutic Options" — contributing
# author
# - Research project: "Knowledge, Attitude, and Practice of Seasonal
# Malarial Chemo-prevention (SMC) among Women of Child-bearing Age" —
# Principal Investigator, 2024 (197 participants, Ilorin South LGA)
# - Other / in progress: [ ]
#
#  8. My Achievements, Honors & Affiliations
#
# Honors:
# - National Phase Qualifier — Nigerian Academy of Neurological Surgeons
# Quiz (2023), Top 6 of 500+
# - Sola Saraki Academic Excellence Grant scholarship (2023/2024)
# - 1st Position — Inter-collegiate Quiz, LAUTECH (2024)
# - 1st Position — Prof. Araoye Inter-collegiate Quiz, Ekiti (2023)
# - 2nd Runner-up — NIMSA May Edition Quizlet(2022), LASU Quiz (2023),
# Prof. Ojuawo Quiz, Medicus OAU (2024)
#
# Professional affiliations:
# - Nigerian Medical Association (NMA) — Member
# - Medical and Dental Council of Nigeria (MDCN) — Registered
# - Ilorin University Medical Student Association (ILUMSA)
# - Research and Journal Club (2023)
#
#  9. My Leadership, Volunteer & Community Work
#
# Leadership:
# - Project Manager — Al-Mustapha Medical Outreach (Dec 2025)
# - Campus Coordinator — Al-Ansor Trust Fund, COHS (2021–2023)
# - Assistant General Secretary — MSSN Nigeria (2022–2023)
# - Student Advisor — UniIlorin Cardiothoracic Surgery Interest Group &
# Mission: Brain
#
# Volunteer / community:
# - MSSN Student Doctor on Call — COHS Hostel (2018–2019)
# - Ilorin Emirate Doctors' Group Outreach — Gambari Community (2022)
# - Power Oil Medical Outreach (2022)
# - Ramadan Special Program Committee (2023)
#
#
#  10. My Goals & What I'm Working Toward
#
# - My 1 goal right now: Become a job-ready Data Scientist / AI
# practitioner Specialist. Planning for residency training in Radiology or
# Community Health. Presently serving, NYSC Member
#
#  11. What I'm Currently Learning
#
# - Data Science & AI fundamentals
# - Python programming
# - PyCharm (code editor)
# - Machine learning, deep learning, generative AI
# - Model deployment
# - Git/GitHub Version Control, LinkedIn, and portfolio building
# AI Bootcamp and Mentorship- MedNexAI Academy, Ongoing
# -  Agentic AI Bootcamp by Miracle, Ongoing
# -  Cloud Computing - Techcrush, Ongoing
# - Learn SPSS from scratch to advanced  in Udemy, Ongoing
# - Data 365 Bootcamp on Udemy, Ongoing
# - Python for Data Science and Machine Learning Masterclass by Jose
# Portilla on Udemy, Ongoing
# - Serving as an NYSC member
#
#
#  12. My Interests & Hobbies
#
# - Professional interests: Neuroscience, public health, medical education,
# data science & AI, content creation
# - Hobbies / things I enjoy: Reading, watching documentaries, playing with
# my wife and daughter, connecting with family
# - Topics I love talking about: Islamic rulings and concepts, Rasheed (
# Preaching Oneness of Allaah), AI, Data Science, Medicine
#
#  13. My Personality, Values & Work Style
#
# - 3 words that describe me: Easy-going, faithful and Hopeful
# - My core values: Discipline and Consistency
# - My strengths: Strong family connection
# - Things I find challenging: Hardship of Nigeria
# - What motivates me: The Quran and Sunnah
#
#  15. How I Like to Be Helped (Preferences)
# I need a remote job to combine with my medical practice. I work flexibly.
#
# - Explain things to me like: a complete beginner — simple words, short
# answers, step by step
# - Tell me exactly what to click or type: Yes
# - Tone I prefer: friendly, encouraging, direct
# - Format I prefer:short steps, bullet points
# - Things to avoid: heavy jargon, very long answers)
# - Correct my mistakes: Yes, gently, and show me the better way
#
#  16. About My AI Assistant
#
# - What I want my AI assistant to help me with: For potential employers to
# interact with it.
# - Tasks I'll use it for most: Job searching
# - Who will use it:Potential employers and anyone seeking to know me
# -

# %%
with open("Resources/Summary.txt", "r", encoding="utf-8") as file:
    summary = file.read()

# %%
openai_api_key = os.getenv("API_TOKEN")
if openai_api_key:
    print(f"OpenAI API Key exists and begins with {openai_api_key[:14]}")
else:
    print(f"OpenAI API Key not set - please check")
# Out:
# OpenAI API Key exists and begins with sk-or-v1-7308c

# %%
name = "Awal Olalekan Abdulrahman"

system_prompt = (
    f"You are acting as {name}, representing {name} on their website. "
    f"Your role is to answer questions specifically about {name}'s career, background, skills, and experience. "
    f"You must faithfully and accurately portray {name} in all interactions. "
    f"You have access to a detailed summary of {name}'s background and their LinkedIn profile, which you should use to inform your answers. "
    f"Maintain a professional, engaging, and approachable tone, as if you are speaking to a potential client or future employer visiting the site. "
    f"If you are unsure of an answer, it is better to honestly acknowledge that than to guess."

    f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{resu_summary}\n\n"
    f"Using this context, please converse naturally and consistently, always staying in character as {name}."
)

# %%
system_prompt
# Out:
# 'You are acting as Awal Olalekan Abdulrahman, representing Awal Olalekan Abdulrahman on their website. Your role is to answer questions specifically about Awal Olalekan Abdulrahman\'s career, background, skills, and experience. You must faithfully and accurately portray Awal Olalekan Abdulrahman in all interactions. You have access to a detailed summary of Awal Olalekan Abdulrahman\'s background and their LinkedIn profile, which you should use to inform your answers. Maintain a professional, engaging, and approachable tone, as if you are speaking to a potential client or future employer visiting the site. If you are unsure of an answer, it is better to honestly acknowledge that than to guess.\n\n## Summary:\nExecutive Profile\nDr. Awal Olalekan Abdulrahman is a highly accomplished Medical Doctor, Data Scientist, Medical Educator, and Researcher based in Ilorin, Kwara State, Nigeria. He uniquely bridges the gap between clinical healthcare, advanced data analytics, and digital education. As the founder of HayMedics Academy, he has successfully built an online community and mentored over 80 medical students across Nigeria.  \nPDF\n+ 2\n\nProfessional Experience\nMedical Intern (House Officer) at Kwara State University Teaching Hospital (Nov 2023 – Nov 2024): Completed comprehensive rotations across major departments, managed over 30 inpatients daily, and assisted in 200+ surgical cases.  \nPDF\n\nFounder & Lead Medical Educator at HayMedics Academy (June 2022 – Present): Authored the 30+ hour "HayMedics Neuro Course," scaling the platform to a 95% satisfaction rate and driving an 85% average improvement in student exam scores.  \nPDF\n\nData Scientist at HayMedics (Feb 2024 – Present): Evaluates healthcare datasets to build predictive disease models, creates clinical research dashboards, and optimizes operational workflows.  \nPDF\n\nFreelance Video Editor & Content Creator at HayMedia (April 2022 – Present): Designs digital content strategies and promotional materials for various healthcare organizations.  \nPDF\n\nEducation & Certifications\nMedical Degree (MBBS): Completed an intensive 8-year program at the University of Ilorin College of Health Sciences (2016 – 2024) with a focus on Neuroscience and Public Health.  \nPDF\n\nClinical & Scientific Training: Earned certifications in Medical Neuroscience from Duke University and Writing in the Sciences from Stanford University via Coursera.  \nPDF\n\nData & Analytics Competency: Certified in Statistics and Data Analysis in SPSS via Aqskill.org (covering parametric/non-parametric inferential modeling and APA reporting) and Data Analytics at Datasphere Academy (covering Python, Power BI, SQL, and Excel).  \nPDF\n\nMultimedia Design: Certified expert in Microsoft PowerPoint via Aqskill.org.  \nPDF\n\nResearch, Publications & Honors\nPeer-Reviewed Publications:\n\nCo-authored a paper on the diagnostic "Centilebrain Model" for mental health disorders published in the Annals of Medicine and Surgery (2024).  \nPDF\n\nContributed to a systematic review regarding endovascular techniques for managing Moyamoya Disease.  \nPDF\n\nField Research: Served as Principal Investigator for a community-based cross-sectional study analyzing the knowledge and practices of Seasonal Malarial Chemo-prevention (SMC) among 197 women in Ilorin South LGA.  \nPDF\n\nAcademic Awards: Ranked in the Top 6 nationally at the Nigerian Academy of Neurological Surgeons Quiz (2023), received an Academic Excellence Grant, and claimed multiple 1st-place championships in regional inter-collegiate quizzes.  \nPDF\n\nCore Skills & Community Impact\nTechnical & Linguistic Toolkit\nClinical: Physical evaluation, emergency response, patient care management, and surgical procedure assistance.  \nPDF\n\nTech & Software: SPSS, R, Python data libraries (Pandas, NumPy), Power BI, SQL, Adobe Premiere Pro, DaVinci Resolve, and medical databases (PubMed, Cochrane, UpToDate).  \nPDF\n\nLanguages: Fluent in English, native in Yoruba, an ...

# %%
openai_python_client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=openai_api_key
)
print("OpenAI Client created", openai_python_client)
# Out:
# OpenAI Client created <openai.OpenAI object at 0x0000017319473690>

# %%
def livechat(message, history):
    messages=[{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai_python_client.chat.completions.create(
        model="google/gemma-4-31b-it:free",
        messages=messages,
        stream=False
    )

    return response.choices[0].message.content

# %%
import requests

key = "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"

r = requests.get(
    "https://openrouter.ai/api/v1/auth/key",
    headers={"Authorization": f"Bearer {key}"}
)
print(r.status_code)
print(r.text)
# Out:
# 200
# {"data":{"label":"sk-or-v1-730...001","is_management_key":false,"is_provisioning_key":false,"limit":null,"limit_reset":null,"limit_remaining":null,"include_byok_in_limit":false,"usage":0,"usage_daily":0,"usage_weekly":0,"usage_monthly":0,"byok_usage":0,"byok_usage_daily":0,"byok_usage_weekly":0,"byok_usage_monthly":0,"is_free_tier":true,"expires_at":null,"creator_user_id":"user_3FH4TNrSknJ5vPChOsJL61y6bZK","rate_limit":{"requests":-1,"interval":"10s","note":"This field is deprecated and safe to ignore."}}}
